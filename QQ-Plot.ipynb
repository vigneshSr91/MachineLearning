# %%
import numpy as np
import pylab
import scipy.stats as stats
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# N(0,1)
std_normal = np.random.normal(loc=0, scale=1, size=1000)

# Print 0 to 100 percentile of standard normal
for i in range(0,101):
    print(i, np.percentile(std_normal, i))
# Out:
# 0 -2.964975102299646
# 1 -2.3485031226310618
# 2 -2.0969957815781397
# 3 -1.9000092405292124
# 4 -1.6931913854389418
# 5 -1.5895496581050688
# 6 -1.5395325858932687
# 7 -1.483806980208585
# 8 -1.4440006803006011
# 9 -1.4085262642283207
# 10 -1.3564770592014097
# 11 -1.2908290820071753
# 12 -1.2215476364382647
# 13 -1.1631325566684567
# 14 -1.1262832586304465
# 15 -1.094552794065818
# 16 -1.031685370563024
# 17 -0.9990428400472314
# 18 -0.970404182130516
# 19 -0.9254961531480594
# 20 -0.8857109294905299
# 21 -0.851390114236535
# 22 -0.8247161884652272
# 23 -0.7698866920423649
# 24 -0.7404710313623668
# 25 -0.7001672376597635
# 26 -0.651368660878398
# 27 -0.609346529445012
# 28 -0.5846835861014309
# 29 -0.5536993324400206
# 30 -0.5194389357389891
# 31 -0.4947479887027156
# 32 -0.46033918075884184
# 33 -0.4355309758785158
# 34 -0.4207532174527143
# 35 -0.38909917081707956
# 36 -0.35598061748301296
# 37 -0.3399241176695214
# 38 -0.30415748196601106
# 39 -0.2866397264296012
# 40 -0.2646691452477094
# 41 -0.23861584134100944
# 42 -0.218068126764481
# 43 -0.2028325406452432
# 44 -0.1882786024796006
# 45 -0.1627179297613192
# 46 -0.1322022919557585
# 47 -0.1141574733385145
# 48 -0.09689053949394022
# 49 -0.0701157495506278
# 50 -0.03817436700667266
# 51 -0.01753395213369251
# 52 -0.0007971611378430067
# 53 0.016321366017643866
# 54 0.03588118023922897
# 55 0.06457461625769921
# 56 0.0848222286374121
# 57 0.10320141795783777
# 58 0.1328565185030645
# 59 0.16059725473108755
# 60 0.18694961603737617
# 61 0.2221039144500046
# 62 0.25075122380814496
# 63 0.2828881742803544
# 64 0.3050945571382839
# 65 0.3323064283047398
# 66 0.38141093626505623
# 67 0.4006492741567309
# 68 0.428665234349585
# 69 0.4563197494913435
# 70 0.4832279035016114
# 71 0.5141017130907644
# 72 0.5406968852575172
# 73 0.5694631496770299
# 74 0.5861658555675346
# 75 0.6140863065585491
# 76 0.6299468708737259
# 77 0.6761203451077044
# 78 0.7262615501813081
# 79 0.7642273052653494
# 80 0.7840447507991158
# 81 0.8164128005782798
# 82 0.8514127261566395
# 83 0.8826656180053446
# 84 0.9208355315769362
# 85 0.9597795281266581
# 86 0.994863014772799
# 87 1.0312282926880383
# 88 1.0883262335552968
# 89 1.15275265925703
# 90 1.2054286086740853
# 91 1.2479971378245285
# 92 1.3178143017345738
# 93 1.365923124247792
# 94 1.448975915882124
# 95 1.5793296819373948
# 96 1.6849063622018279
# 97 1.7867263277853562
# 98 1.9520349017686562
# 99 2.2414782806262306
# 100 4.180236612739594

# %%
# generate 100 sample for N(20,5)
measurements = np.random.normal(loc=20, scale=5, size=100)

stats.probplot(measurements, dist='norm', plot=pylab)
pylab.show()

# %%
measurements = np.random.uniform(low=-1, high=1, size=10000)

stats.probplot(measurements, dist='norm', plot=pylab)
pylab.show()
